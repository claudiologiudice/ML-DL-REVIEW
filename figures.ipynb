# %%
library(DBI)
library(dplyr)
library(RSQLite)
con <- dbConnect(RSQLite::SQLite(), "ML_DL_review_articles.db")
RSQLite::initRegExp(con)

id_NB <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP '[Nn]a[iï]ve [Bb]ayes'")[[1]]   #28
id_LDA <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP '[Ll]inear [Dd]iscriminant [Aa]nalysis'")[[1]]  #14
id_LM <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP '[Ll]inear [Rr]egression'")[[1]]  
#Union 
id_LinearModel <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP '[Ll]inear [Mm]odel'")[[1]]    #for a total of 21
id_LR <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP '[Ll]ogistic [Rr]egression'")[[1]]
#Union 
id_LogisticModel <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP '[Ll]ogistic [Mm]odel'")[[1]]  #for a total of 38
id_SVM <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP '[Ss]upport [Vv]ector [Mm]achine'")[[1]]  
id_SVM_ <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP 'SVM'")[[1]] 
#length(id_SVM)+length(id_SVM_)-length(intersect(id_SVM,id_SVM_)) #for a total of 157
id_Per <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP '[Pp]erceptron'")[[1]] # 12
id_ANN <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP '[Aa]rtificial [Nn]eural [Nn]etwork'")[[1]] # 25
id_Boo <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP '[Bb]oosting'")[[1]] # 21
id_ABoo <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP '[Aa]da[Bb]oost'")[[1]] # 5
id_GBoo <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP '[Gg]radient [Bb]oosting'")[[1]] #8
id_RF <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP '[Rr]andom [Ff]orest'")[[1]] #124
id_KNN <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP '[Kk]-[Nn]earest'")[[1]]
id_CNN <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP '[Cc]onvolutional [Nn]eural [Nn]etwork'")[[1]] 
#union 
id_CNN_ <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP 'CNN'")[[1]] 
length(id_CNN)+length(id_CNN_)-length(intersect(id_CNN,id_CNN_)) #for a total o f 35
id_RNN <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP '[Rr]ecurrent [Nn]eural [Nn]etwork'")[[1]]  
#union
id_RNN_ <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP 'RNN'")[[1]] 
length(id_RNN)+length(id_RNN_)-length(intersect(id_RNN,id_RNN_)) #6
id_KM <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP '[Kk]-[Mm]ean'")[[1]] # 8
id_AE <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP '[Aa]utoencoder'")[[1]] # 24
id_SO <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP '[Ss]elf [Oo]rganizing'")[[1]]  #7
id_GA <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP '[Gg]enerative [Aa]dversarial'")[[1]] #3
id_Boruta <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP '[Bb]oruta'")[[1]] #2
id_ForwardSe <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP '[Ff]orward [Ss]election'")[[1]] # 22369383
id_BackE <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP '[Bb]ackward [Ee]limination'")[[1]] # 25527049
id_StepS <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP '[St]tepwise [Ss]election'")[[1]] #0
id_lasso <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP '[Ll][Aa][Ss][Ss][Oo]'")[[1]] #31
id_Ridge <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP ' [Rr]idge '")[[1]] #6
id_EN <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP '[Ee]lastic [Nn]et'")[[1]] #13
id_Reinf <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP '[Rr]einforcement [Ll]earning'")[[1]] #2
                                                
id_PCA_ <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP ' PCA '")[[1]]   #28
id_PCA <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP '[Pp]rincipal [Cc]omponent [Aa]nalysis'")[[1]]   #28

id_DNN_ <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP ' DNN '")[[1]]   #28
id_DNN__ <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP ' DNNs '")[[1]]   #28
id_DNN <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP '[Dd]eep [Nn]eural [Nn]etwork'")[[1]]   #

#pdf("mentions.pdf", width=5, height=5, pointsize=10)
methods = c("Principal Component Analysis","Deep Neural network","Naive Bayes", "Linear Discriminant Analysis", "Linear Regression", "LASSO", "Ridge Regression", "Elastic Net", "Logistic Regression", "Support Vector Machine", "Perceptron", "Artificial Neural Network", "Boosting", "Random Forest", "K-Nearest Neighbor", "Convolutional Neural Network", "Recurrent Neural Network", "K-means", "Autoencoder", "Self Organizing Map", "Generative Adversarial Network", "Reinforcement Learning")
n_papers=c(19,36,28,14,21,31,6,13,38,157,12,25,21,124,28,35,6,8,24,7,3,2) 
par(oma=c(1.5,6,0,0),cex.axis=0.7, cex.lab=0.7, cex.main=0.4)
index=order(n_papers)
barplot(n_papers[index], horiz=TRUE,names.arg=methods[index], cex.names=0.7, las=1, xlab="number of mentions")
dev.off()
# Out:
# [1] 35
# [1] 6
# pdf
#   2

# %%
f = seq(-5,4,0.001)
loss01 = function(z){return(ifelse(z<=0,1,0))}
perceptron = function(z){return(sapply(z,function(x){return(max(0,-x));}))}
hinge = function(z){return(sapply(z, function(x){return(max(0, 1-x))}))}
logloss = function(z){return(sapply(z, function(x){return((1/log(2))*log(1+exp(-2*x)))}))}
sigmoidloss = function(z){return(sapply(z, function(x){return(1-1/(1+exp(-x)))}))}

colors=c("black","blue","red","cyan")
linetype=c(1,2,3,4)

#pdf("losses.pdf", width=5, height=5, pointsize=10)
plot(f, loss01(f), type='l', ylim=c(-1,4), cex.lab=1, col=colors[1], lty=1, xlab="z=y·f(x)", ylab="Loss size")
points(f, perceptron(f), type='l', col=colors[2], lty=2)
points(f, hinge(f), type='l', col=colors[3], lty=3)
#points(f, sigmoidloss(f), type='l', col=colors[4], lty=linetype[4])
points(f, logloss(f), type='l', col=colors[4], lty=4)
#points(f, -tanh(f), type='l', col=colors[6], lty=linetype[6])
legend(1.5, 4, legend=c("0-1", "perceptron", "hinge", "log"),
       col=colors, lty=linetype, cex=1, bty = "n")
text(-2.7, -1, "incorrectly classified yf(x)<0", cex=1, col="dark gray")
text(2.2, -1, "correctly classified yf(x)>=0", cex=1, col="dark gray")
#segments(1,-1.5,1,-0.7, lty=2, col="dark gray", lwd=2)
segments(1,-0.4,1,4, lty=2, col="dark gray")
text(0.5, -0.3, "yf(x)<1", cex=0.9, col="red")
segments(0,-1.5,0,0, lty=2, col="dark gray")
dev.off()
# Out:
# null device
#           1
# plot without title

# %%
perceptron2 = function(z){return(sapply(z, function(x){return(max(0,x));}))}
loss01 = function(z){return(ifelse(z>=0,1,0))}
sigmoid = function(z){return(sapply(z, function(x){return(1/(1+exp(-x)))}))}

colors=c("black","blue","brown","green")
linetype=c(1,2,5,6)

#pdf("activation_function.pdf", width=5, height=5, pointsize=10)
plot(f, loss01(f), ylim=c(-1.5,1.5), cex.lab=1, type='l', col=colors[1], lty=1, xlab="s", ylab="F")
points(f, perceptron2(f), type='l', col=colors[2], lty=2)
points(f, sigmoid(f), type='l', col=colors[3], lty=5)
points(f, tanh(f), type='l', col=colors[4], lty=6)
legend(0.5, -0.5, legend=c("0-1", "ReLu", "Sigmoid", "Hyperbolic Tangent"),col=colors, lty=linetype, cex=1, bty = "n")


dev.off()
# Out:
# null device
#           1
# plot without title

# %%
library(DBI)
library(dplyr)
library(RSQLite)
con <- dbConnect(RSQLite::SQLite(), "ML_DL_review_articles.db")
RSQLite::initRegExp(con)

id_NB <- dbGetQuery(con, "SELECT PMID FROM ML_DL_review_articles WHERE Abstract REGEXP '[Nn]a[iï]ve [Bb]ayes'")[[1]]   #28
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
#dbGetQuery(con, "SELECT Abstract FROM ML_DL_review_articles WHERE Abstract REGEXP '[Nn]a[iï]ve [Bb]ayes'")[[1]]   #28
